# %%
from covid_analyzer import CovidDataAnalyzer

# 1. Initialize the class with covid_data.csv.
analyzer = CovidDataAnalyzer()
analyzer.load_data('datasets/country_wise_latest.csv')
# analyzer.load_data('datasets/covid_19_clean_complete.csv')
# analyzer.load_data('datasets/worldometer_data.csv')

# 2. Load and describe the dataset.
analyzer.describe_data()

# 3. Handle missing values.
# analyzer.handle_missing_values()

# 4. Apply the filter_high_cases method and save the filtered data.
analyzer.filter_high_cases()

# 5. Apply the filter_by_date_range method for a specific range (e.g., March 2020 to June 2020) and save the filtered data.
# analyzer.load_data('datasets/day_wise.csv')
# analyzer.filter_by_date_range('2020-03-01', '2020-06-30')

# 6. Calculate and display global statistics.
# analyzer.calculate_global_statistics()

# 7. Provide insights
analyzer.generate_insights()

# 8. Test save a file
# analyzer.save_filtered_data("datasets/high_impact_covid_data.csv")
# Out:
# Data loaded successfully: 187 rows, 15 columns
#
# ==================================================
#                  DATASET OVERVIEW
# ==================================================
# ### 1. Dataset Shape
# Shape: 187 rows, 15 columns
#
# ### 2. Column Information and Null Counts
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Columns: 15 entries, Country/Region to WHO Region
# dtypes: float64(4), int64(9), object(2)
# ### 3. Basic Descriptive Statistics (Numerical)
#                         count          mean            std    min        25%  \
# Confirmed               187.0  88130.935829  383318.663831  10.00  1114.0000
# Deaths                  187.0   3497.518717   14100.002482   0.00    18.5000
# Recovered               187.0  50631.481283  190188.189643   0.00   626.5000
# Active                  187.0  34001.935829  213326.173371   0.00   141.5000
# New cases               187.0   1222.957219    5710.374790   0.00     4.0000
# New deaths              187.0     28.957219     120.037173   0.00     0.0000
# New recovered           187.0    933.812834    4197.719635   0.00     0.0000
# Deaths / 100 Cases      187.0      3.019519       3.454302   0.00     0.9450
# Recovered / 100 Cases   187.0     64.820535      26.287694   0.00    48.7700
# Deaths / 100 Recovered  182.0     40.558297     336.669357   0.00     1.4425
# Confirmed last week     187.0  78682.475936  338273.676567  10.00  1051.5000
# 1 week change           187.0   9448.459893   47491.127684 -47.00    49.0000
# 1 week % increase       187.0     13.606203      24.509838  -3.84     2.7750
#
#                             50%         75%         max
# Confirmed               5059.00  40460.5000  4290259.00
# Deaths                   108.00    734.0000   148011.00
# Recovered               2815.00  22606.0000  1846641.00
# Active                  1600.00   9149.0000  2816444.00
# New cases                 49.00    419.5000    56336.00
# New deaths                 1.00      6.0000     1076.00
# New recovered             22.00    221.0000    33728.00
# Deaths / 100 Cases         2.15      3.8750       28.56
# Recovered / 100 Cases     71.32     86.8850      100.00
# Deaths / 100 Recovered     3.58      6.2325     3259.26
# Confirmed last week     5020.00  37080.5000  3834677.00
# 1 week change            432.00   3172.0000   455582.00
# 1 week % increase          6.89     16.8550      226.32
#
# ### 4. Basic Descriptive Statistics (Categorical/Object)
#                count unique          top freq
# Country/Region   187    187  Afghanistan    1
# WHO Region       187      6       Europe   56
#
# --- Missing Values Per Column ---
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    5
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64
# ==================================================
#
# ==================================================
#           APPLYING HIGH-CASE FILTER
# ==================================================
# Original dataset size: 187 rows
# Filtered dataset size: 18 rows
# Filtered data saved successfully to **self.filtered_data**.
#
# =======================================================
#                  AUTOMATED DATA INSIGHTS
# =======================================================
# There are 187 countries in the dataset.
# The country with the highest confirmed cases is US with 4,290,259 cases.
# The country with the lowest confirmed cases is Western Sahara with 10 cases.
# On average, countries reported about 88,131 confirmed cases.
# The overall global death rate is approximately 3.97% (654,036 deaths out of 16,480,485 confirmed cases).
#
# Some columns contain missing values:
#  - Deaths / 100 Recovered: 5 missing entries
# =======================================================
